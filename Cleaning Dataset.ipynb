# %%
# TEAM: AI ML 07 

#### Team Members:  1.Sneha Sable   2. Hrutik Naik   3. Shravani Dhuri   4. Shrumi Dedhia  5. Vikram Rao 

#### Problem Statement: Gather data on companies like Walmart, IKEA etc. Try to visualize and identify any trend useful for the company. Implementation of a model for predicting the sales of the most/least sold product for future campaigns.

# %% [markdown]
# # CLEANING DATASET

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('walmart_dataset.csv', parse_dates=['Date'])
data.head()
# Out:
#    Store Type    Size       Date  Temperature  Fuel_Price  MarkDown1  \
# 0      1    A  151315 2010-02-05        42.31       2.572        NaN
# 1     35    B  103681 2010-02-05        27.19       2.784        NaN
# 2     35    B  103681 2010-02-05        27.19       2.784        NaN
# 3     35    B  103681 2010-02-05        27.19       2.784        NaN
# 4     35    B  103681 2010-02-05        27.19       2.784        NaN
#
#    MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0        NaN        NaN        NaN        NaN  211.096358         8.106
# 1        NaN        NaN        NaN        NaN  135.352461         9.262
# 2        NaN        NaN        NaN        NaN  135.352461         9.262
# 3        NaN        NaN        NaN        NaN  135.352461         9.262
# 4        NaN        NaN        NaN        NaN  135.352461         9.262
#
#    IsHoliday  Dept  Weekly_Sales
# 0      False     1      24924.50
# 1      False     3      14612.19
# 2      False     4      26323.15
# 3      False     5      36414.63
# 4      False     6      11437.81

# %%
pd.DataFrame(data.dtypes, columns=['Type'])
# Out:
#                         Type
# Store                  int64
# Type                  object
# Size                   int64
# Date          datetime64[ns]
# Temperature          float64
# Fuel_Price           float64
# MarkDown1            float64
# MarkDown2            float64
# MarkDown3            float64
# MarkDown4            float64
# MarkDown5            float64
# CPI                  float64
# Unemployment         float64
# IsHoliday               bool
# Dept                   int64
# Weekly_Sales         float64

# %%
data['Week'] = data.Date.dt.week
data['Day'] = data.Date.dt.day
data['Month'] = data.Date.dt.month
data['Year'] = data.Date.dt.year
data.head()
# Out:
#    Store Type    Size       Date  Temperature  Fuel_Price  MarkDown1  \
# 0      1    A  151315 2010-02-05        42.31       2.572        NaN
# 1     35    B  103681 2010-02-05        27.19       2.784        NaN
# 2     35    B  103681 2010-02-05        27.19       2.784        NaN
# 3     35    B  103681 2010-02-05        27.19       2.784        NaN
# 4     35    B  103681 2010-02-05        27.19       2.784        NaN
#
#    MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0        NaN        NaN        NaN        NaN  211.096358         8.106
# 1        NaN        NaN        NaN        NaN  135.352461         9.262
# 2        NaN        NaN        NaN        NaN  135.352461         9.262
# 3        NaN        NaN        NaN        NaN  135.352461         9.262
# 4        NaN        NaN        NaN        NaN  135.352461         9.262
#
#    IsHoliday  Dept  Weekly_Sales  Week  Day  Month  Year
# 0      False     1      24924.50     5    5      2  2010
# 1      False     3      14612.19     5    5      2  2010
# 2      False     4      26323.15     5    5      2  2010
# 3      False     5      36414.63     5    5      2  2010
# 4      False     6      11437.81     5    5      2  2010

# %%
store_counts = (data['Store']
                .value_counts()
                .sort_index()
                .to_frame(name="Count")
                .reset_index()
                .rename(columns= {'index': 'Store'}))
store_counts['Percent'] = (store_counts['Count'] / store_counts['Count'].sum()) * 100
store_counts
# Out:
#     Store  Count   Percent
# 0       1  10244  2.429964
# 1       2  10238  2.428541
# 2       3   9036  2.143416
# 3       4  10272  2.436606
# 4       5   8999  2.134640
# 5       6  10211  2.422136
# 6       7   9762  2.315630
# 7       8   9895  2.347178
# 8       9   8867  2.103328
# 9      10  10315  2.446806
# 10     11  10062  2.386792
# 11     12   9705  2.302109
# 12     13  10474  2.484522
# 13     14  10040  2.381574
# 14     15   9901  2.348602
# 15     16   9443  2.239960
# 16     17   9864  2.339825
# 17     18   9859  2.338639
# 18     19  10148  2.407192
# 19     20  10214  2.422848
# 20     21   9582  2.272932
# 21     22   9688  2.298076
# 22     23  10050  2.383946
# 23     24  10228  2.426169
# 24     25   9804  2.325592
# 25     26   9854  2.337453
# 26     27  10225  2.425457
# 27     28  10113  2.398890
# 28     29   9455  2.242807
# 29     30   7156  1.697464
# 30     31  10142  2.405769
# 31     32  10202  2.420001
# 32     33   6487  1.538772
# 33     34  10224  2.425220
# 34     35   9528  2.260123
# 35     36   6222  1.475911
# 36     37   7206  1.709325
# 37     38   7362  1.746329
# 38     39   9878  2.343146
# 39     40  10017  2.376118
# 40     41  10088  2.392960
# 41     42   6953  1.649311
# 42     43   6751  1.601395
# 43     44   7169  1.700548
# 44     45   9637  2.285979

# %%
print("Store with more registers:\n", store_counts.iloc[store_counts['Percent'].idxmax()], "\n")
print("Store with more registers:\n", store_counts.iloc[store_counts['Percent'].idxmin()])
# Out:
# Store with more registers:
#  Store         13.000000
# Count      10474.000000
# Percent        2.484522
# Name: 12, dtype: float64
#
# Store with more registers:
#  Store        36.000000
# Count      6222.000000
# Percent       1.475911
# Name: 35, dtype: float64

# %%
type_counts = pd.DataFrame(data['Type']
                .value_counts()
                .sort_index()
                .to_frame(name="Count")
                .reset_index()
                .rename(columns= {'index': 'Type'}))
type_counts['Percent'] = (type_counts['Count'] / type_counts['Count'].sum()) * 100
type_counts
# Out:
#   Type   Count    Percent
# 0    A  215478  51.113220
# 1    B  163495  38.782409
# 2    C   42597  10.104372

# %%
print("Type with more registers:\n", type_counts.iloc[type_counts['Percent'].idxmax()], "\n")
print("Type with more registers:\n", type_counts.iloc[type_counts['Percent'].idxmin()])
# Out:
# Type with more registers:
#  Type             A
# Count       215478
# Percent    51.1132
# Name: 0, dtype: object
#
# Type with more registers:
#  Type             C
# Count        42597
# Percent    10.1044
# Name: 2, dtype: object

# %%
dept_counts = pd.DataFrame(data['Dept']
                .value_counts()
                .sort_index()
                .to_frame(name="Count")
                .reset_index()
                .rename(columns= {'index': 'Dept'}))
dept_counts['Percent'] = (dept_counts['Count'] / dept_counts['Count'].sum()) * 100
dept_counts
# Out:
#     Dept  Count   Percent
# 0      1   6435  1.526437
# 1      2   6435  1.526437
# 2      3   6435  1.526437
# 3      4   6435  1.526437
# 4      5   6347  1.505563
# ..   ...    ...       ...
# 76    95   6435  1.526437
# 77    96   4854  1.151410
# 78    97   6278  1.489195
# 79    98   5836  1.384349
# 80    99    862  0.204474
#
# [81 rows x 3 columns]

# %%
print("Department with more registers:\n", dept_counts.iloc[dept_counts['Percent'].idxmax()], "\n")
print("Department with more registers:\n", dept_counts.iloc[dept_counts['Percent'].idxmin()])
# Out:
# Department with more registers:
#  Dept          1.000000
# Count      6435.000000
# Percent       1.526437
# Name: 0, dtype: float64
#
# Department with more registers:
#  Dept       43.000000
# Count      12.000000
# Percent     0.002847
# Name: 41, dtype: float64

# %%
holiday_counts = (data['IsHoliday']
                .value_counts()
                .sort_index()
                .to_frame(name="Count")
                .reset_index()
                .rename(columns= {'index': 'IsHoliday'}))
holiday_counts['Percent'] = (holiday_counts['Count'] / holiday_counts['Count'].sum()) * 100
holiday_counts
# Out:
#    IsHoliday   Count    Percent
# 0      False  391909  92.964158
# 1       True   29661   7.035842

# %%
print("IsHoliday with more registers:\n", holiday_counts.iloc[holiday_counts['Percent'].idxmax()], "\n")
print("IsHoliday with more registers:\n", holiday_counts.iloc[holiday_counts['Percent'].idxmin()])
# Out:
# IsHoliday with more registers:
#  IsHoliday      False
# Count         391909
# Percent      92.9642
# Name: 0, dtype: object
#
# IsHoliday with more registers:
#  IsHoliday       True
# Count          29661
# Percent      7.03584
# Name: 1, dtype: object

# %% [markdown]
# ### Count the missing values

# %%
cols = (data.isnull().sum(axis=0)/len(data)).sort_values(ascending=False).index

null_count = data.isnull().sum(axis=0)
null_percent = null_count/len(data) * 100

null_data = pd.concat([null_count, null_percent], axis=1)
null_data = null_data.rename(columns={0: 'Null count', 1: 'Null percent'})
null_data = null_data[null_data['Null count']!=0]
null_data
# Out:
#            Null count  Null percent
# MarkDown1      270889     64.257181
# MarkDown2      310322     73.611025
# MarkDown3      284479     67.480845
# MarkDown4      286603     67.984676
# MarkDown5      270138     64.079038

# %%
data = data.drop(['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5'], axis=1)

# %%
data.columns
# Out:
# Index(['Store', 'Type', 'Size', 'Date', 'Temperature', 'Fuel_Price', 'CPI',
#        'Unemployment', 'IsHoliday', 'Dept', 'Weekly_Sales', 'Week', 'Day',
#        'Month', 'Year'],
#       dtype='object')

# %%
data['IsHoliday'] = data['IsHoliday'].apply(lambda x: 1 if x == True else 0)
data['IsHoliday'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.describe()
# Out:
#                Store           Size    Temperature     Fuel_Price  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546  136727.915739      60.090059       3.361027
# std        12.785297   60980.583328      18.447931       0.458515
# min         1.000000   34875.000000      -2.060000       2.472000
# 25%        11.000000   93638.000000      46.680000       2.933000
# 50%        22.000000  140167.000000      62.090000       3.452000
# 75%        33.000000  202505.000000      74.280000       3.738000
# max        45.000000  219622.000000     100.140000       4.468000
#
#                  CPI   Unemployment      IsHoliday           Dept  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean      171.201947       7.960289       0.070358      44.260317
# std        39.159276       1.863296       0.255750      30.492054
# min       126.064000       3.879000       0.000000       1.000000
# 25%       132.022667       6.891000       0.000000      18.000000
# 50%       182.318780       7.866000       0.000000      37.000000
# 75%       212.416993       8.572000       0.000000      74.000000
# max       227.232807      14.313000       1.000000      99.000000
#
#         Weekly_Sales           Week            Day          Month  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean    15981.258123      25.826762      15.673131       6.449510
# std     22711.183519      14.151887       8.753549       3.243217
# min     -4988.940000       1.000000       1.000000       1.000000
# 25%      2079.650000      14.000000       8.000000       4.000000
# 50%      7612.030000      26.000000      16.000000       6.000000
# 75%     20205.852500      38.000000      23.000000       9.000000
# max    693099.360000      52.000000      31.000000      12.000000
#
#                 Year
# count  421570.000000
# mean     2010.968591
# std         0.796876
# min      2010.000000
# 25%      2010.000000
# 50%      2011.000000
# 75%      2012.000000
# max      2012.000000

# %%
print('Total of weeks with negative sales')
data.loc[data.Weekly_Sales<0].shape
# Out:
# Total of weeks with negative sales
# (1285, 15)

# %%
data = data.loc[data.Weekly_Sales>0].reset_index(drop=True)

# %%
data = pd.get_dummies(data)

# %%
data.columns
# Out:
# Index(['Store', 'Size', 'Date', 'Temperature', 'Fuel_Price', 'CPI',
#        'Unemployment', 'IsHoliday', 'Dept', 'Weekly_Sales', 'Week', 'Day',
#        'Month', 'Year', 'Type_A', 'Type_B', 'Type_C'],
#       dtype='object')

# %% [markdown]
# # HEATMAP

# %%
sns.set_style('ticks')
corr = data.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)]=True

f,ax = plt.subplots(figsize=(20,15))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

fig = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, annot=True,
            linewidths=.2, cbar_kws={"shrink": .5})

# %%
data.to_csv('walmart_clean.csv', index=None)
